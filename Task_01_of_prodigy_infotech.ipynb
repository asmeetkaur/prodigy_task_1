# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('/content/world_population.csv',  encoding='utf-8')
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
# View DataFrame and column names
print(df.head())
print(df.columns)
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df = pd.DataFrame(data)

# Drop specific columns
df_final = df.drop(['Rank', 'CCA3', 'Capital', 'Continent', 'Area (km²)', 'Density (per km²)',
                    'Growth Rate', 'World Population Percentage'], axis=1)

# Display the DataFrame after dropping columns
print(df_final)
# Out:
#      Country/Territory  2022 Population  2020 Population  2015 Population  \
# 0          Afghanistan         41128771         38972230         33753499
# 1              Albania          2842321          2866849          2882481
# 2              Algeria         44903225         43451666         39543154
# 3       American Samoa            44273            46189            51368
# 4              Andorra            79824            77700            71746
# ..                 ...              ...              ...              ...
# 229  Wallis and Futuna            11572            11655            12182
# 230     Western Sahara           575986           556048           491824
# 231              Yemen         33696614         32284046         28516545
# 232             Zambia         20017675         18927715         16248230
# 233           Zimbabwe         16320537         15669666         14154937
#
#      2010 Population  2000 Population  1990 Population  1980 Population  \
# ...

# %%
# Extracting the population data
population_data = df['2022 Population']

# %%
# Creating the histogram
plt.figure(figsize=(10, 6))
plt.hist(population_data, bins=10, color='pink', edgecolor='black')
plt.title('Distribution of Population in 2022')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Extracting continent names and their corresponding counts
continents = df['Continent']
continent_counts = continents.value_counts()

# Creating the bar chart
plt.figure(figsize=(8, 6))
continent_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Countries in Each Continent')
plt.xlabel('Continent')
plt.ylabel('Number of Countries')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
